# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator


qc=QuantumCircuit(2,1)


qc.h(0)

qc.cx(0,1)


qc.measure(0,0)



print(qc)


sim=AerSimulator()


result=sim.run(
    qc,
    shots=1000
).result()


print(
result.get_counts()
)
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├
#      └───┘┌─┴─┐└╥┘
# q_1: ─────┤ X ├─╫─
#           └───┘ ║
# c: 1/═══════════╩═
#                 0
# {'1': 465, '0': 535}
